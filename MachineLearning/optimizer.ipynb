# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
x=np.linspace(0,10,50)
true_m, true_c=2,1
y=true_m*x+true_c+np.random.normal(0,2,x.shape)

# %%
m,c=0.0,0.0
learning_rate=0.01
iterations=1000

# %%
loss_history=[]

# %%
for i in range(iterations):
    y_pred=m*x+c
   m_grad=(-2*len(x))*np.sum(X*(y-y_pred))
c_grad=(-2/len(x))*np.sum(y-y_pred)
m=m_learning_rate*m_grad
c=c_learning_rate*c_grad
# Track loss (Mean Squared Error)
loss = np.mean((Y - Y_predicted)**2)
loss_history.append(loss)
# Pf
